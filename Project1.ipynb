# %%
#import libraries
import pandas as pd
import numpy as np

#load csv file data with headers
location = "DC_Properties.csv"
DCprops = pd.read_csv(location)

# %%
DCprops.head(11)
# Out:
#     BATHRM  HF_BATHRM        HEAT AC  NUM_UNITS  ROOMS  BEDRM  \
# 0        2          1  Forced Air  Y        2.0      9      3
# 1        2          1  Forced Air  Y        1.0      7      3
# 2        2          0  Forced Air  Y        1.0      6      3
# 3        1          0   Warm Cool  N        1.0      6      3
# 4        2          0  Forced Air  Y        1.0      7      3
# 5        2          0     Ht Pump  Y        1.0      9      3
# 6        3          1  Forced Air  Y        1.0      7      4
# 7        4          1     Ht Pump  Y        1.0     12      6
# 8        3          1   Warm Cool  Y        1.0     12      5
# 9        4          1  Forced Air  Y        1.0     13      6
# 10       3          1  Forced Air  Y        1.0      6      2
#
#     Approx_YearBuilt  YR_RMDL   EYB   ...      LATITUDE  LONGITUDE  \
# 0             1870.0   1980.0  1967   ...     38.914978 -77.034037
# 1             1890.0   1963.0  1982   ...     38.891294 -76.999762
# ...

# %%
DCprops.columns
# Out:
# Index(['BATHRM', 'HF_BATHRM', 'HEAT', 'AC', 'NUM_UNITS', 'ROOMS', 'BEDRM',
#        'Approx_YearBuilt', 'YR_RMDL', 'EYB', 'STORIES', 'Sale_Date', 'PRICE',
#        'QUALIFIED', 'SALE_NUM', 'GBA', 'BLDG_NUM', 'STYLE', 'STRUCT', 'GRADE',
#        'CNDTN', 'EXTWALL', 'ROOF', 'INTWALL', 'KITCHENS', 'FIREPLACES',
#        'USECODE', 'LANDAREA', 'SOURCE', 'CMPLX_NUM', 'LIVING_GBA',
#        'FULLADDRESS', 'CITY', 'STATE', 'ZIPCODE', 'NATIONALGRID', 'LATITUDE',
#        'LONGITUDE', 'LAT_LONG', 'ASSESSMENT_NBHD', 'ASSESSMENT_SUBNBHD',
#        'CENSUS_TRACT', 'CENSUS_BLOCK', 'WARD', 'SQUARE', 'QUADRANT'],
#       dtype='object')

# %%
DCprops.dtypes
# Out:
# BATHRM                  int64
# HF_BATHRM               int64
# HEAT                   object
# AC                     object
# NUM_UNITS             float64
# ROOMS                   int64
# BEDRM                   int64
# Approx_YearBuilt      float64
# YR_RMDL               float64
# EYB                     int64
# STORIES               float64
# Sale_Date              object
# PRICE                 float64
# QUALIFIED              object
# SALE_NUM                int64
# GBA                   float64
# BLDG_NUM                int64
# STYLE                  object
# STRUCT                 object
# GRADE                  object
# CNDTN                  object
# EXTWALL                object
# ROOF                   object
# INTWALL                object
# KITCHENS              float64
# FIREPLACES              int64
# USECODE                 int64
# LANDAREA                int64
# SOURCE                 object
# CMPLX_NUM             float64
# LIVING_GBA            float64
# ...

# %%
dupe = DCprops.duplicated() #creates list of True/False values; need the next line to see actual names
DCprops[dupe] #shows rows where duplicated is True
# Out:
#         BATHRM  HF_BATHRM        HEAT AC  NUM_UNITS  ROOMS  BEDRM  \
# 107394       1          0     Ht Pump  Y        NaN      4      2
# 107395       1          0     Ht Pump  Y        NaN      4      2
# 107396       1          0     Ht Pump  Y        NaN      4      2
# 107398       1          0     Ht Pump  Y        NaN      4      2
# 107399       1          0     Ht Pump  Y        NaN      4      2
# 108726       1          0  Forced Air  Y        NaN      4      3
# 109422       1          0     Ht Pump  Y        NaN      3      1
# 110910       1          0  Forced Air  Y        NaN      4      2
# 110912       1          0  Forced Air  Y        NaN      4      2
# 111194       1          0     Ht Pump  Y        NaN      4      2
# 111195       1          0     Ht Pump  Y        NaN      3      1
# 111354       1          0     Ht Pump  Y        NaN      4      2
# 111387       1          0  Forced Air  Y        NaN      3      1
# ...

# %%
DCprops.sort_values('PRICE')
# Out:
#         BATHRM  HF_BATHRM            HEAT AC  NUM_UNITS  ROOMS  BEDRM  \
# 71647        3          0      Forced Air  N        3.0     14      6
# 73537        1          1   Hot Water Rad  N        1.0      7      3
# 151799       2          0   Hot Water Rad  N        NaN      6      3
# 151684       2          0      Forced Air  Y        NaN      4      2
# 109128       1          0      Forced Air  Y        NaN      3      1
# 1391         2          1   Hot Water Rad  N        2.0      8      3
# 46753        2          0   Hot Water Rad  N        1.0      8      3
# 76809        1          0   Hot Water Rad  N        1.0      6      3
# 5140         1          0   Hot Water Rad  N        1.0      5      2
# 79554        3          1      Forced Air  Y        2.0     10      5
# 74034        3          1      Forced Air  Y        3.0      8      3
# 74035        2          0      Forced Air  N        1.0      8      5
# ...

# %%
DCprops.describe()
# Out:
#               BATHRM      HF_BATHRM      NUM_UNITS          ROOMS  \
# count  158957.000000  158957.000000  106696.000000  158957.000000
# mean        1.810678       0.458237       1.198039       6.187736
# std         0.976396       0.587571       0.596924       2.618165
# min         0.000000       0.000000       0.000000       0.000000
# 25%         1.000000       0.000000       1.000000       4.000000
# 50%         2.000000       0.000000       1.000000       6.000000
# 75%         2.000000       1.000000       1.000000       7.000000
# max        14.000000      11.000000       6.000000      48.000000
#
#                BEDRM  Approx_YearBuilt       YR_RMDL            EYB  \
# count  158957.000000     158686.000000  80928.000000  158957.000000
# mean        2.732506       1941.987579   1998.243537    1963.718024
# std         1.358864         33.640234     16.575786      24.923150
# min         0.000000       1754.000000     20.000000    1800.000000
# ...

# %%
pd.pivot_table(DCprops, values=['PRICE'], index=['BEDRM'])
# Out:
#               PRICE
# BEDRM
# 0      1.992876e+06
# 1      1.927088e+06
# 2      6.482021e+05
# 3      4.821091e+05
# 4      6.659285e+05
# 5      1.042489e+06
# 6      1.266913e+06
# 7      1.721509e+06
# 8      8.107116e+05
# 9      2.718745e+06
# 10     6.924450e+05
# 11     1.025980e+06
# 12     1.547980e+06
# 13     4.425000e+05
# 14     9.250000e+05
# 15     1.105000e+06
# 20     1.900000e+06
